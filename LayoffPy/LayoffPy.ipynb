# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Read in layoff csv data and show
layoff_DF = pd.read_csv("Resources/layoffs_data.csv")
layoff_DF.head()
# Out:
#         Company  Location_HQ        Industry  Laid_Off_Count  Percentage  \
# 0  Thoughtworks      Chicago           Other           500.0        0.04
# 1         iFood    Sao Paulo            Food           355.0        0.06
# 2         Waymo  SF Bay Area  Transportation           209.0        0.08
# 3        PayFit        Paris              HR           200.0        0.20
# 4     Yellow.ai  SF Bay Area         Support           200.0         NaN
#
#             Date                                             Source  \
# 0  3/1/2023 0:00  https://techcrunch.com/2023/03/01/thoughtworks...
# 1  3/1/2023 0:00  https://economia.uol.com.br/noticias/redacao/2...
# 2  3/1/2023 0:00  https://www.theinformation.com/articles/alphab...
# 3  3/1/2023 0:00  https://www.lesechos.fr/start-up/next40-vivate...
# 4  3/1/2023 0:00  https://inc42.com/buzz/conversational-ai-start...
#
#    Funds_Raised       Stage     Date_Added        Country  \
# 0         748.0    Post-IPO  3/2/2023 4:06  United States
# 1        2100.0  Subsidiary  3/2/2023 4:13         Brazil
# 2        5500.0  Subsidiary  3/2/2023 4:08  United States
# 3         495.0    Series E  3/2/2023 4:17         France
# 4         102.0    Series C  3/2/2023 4:12  United States
#
#   List_of_Employees_Laid_Off
# 0                    Unknown
# 1                    Unknown
# 2                    Unknown
# 3                    Unknown
# 4                    Unknown

# %%
#Clean data to only focus on Countries headquartered in the United States
US_layoff_DF = layoff_DF.loc[layoff_DF["Country"]=="United States"]

#Show the data
US_layoff_DF
# Out:
#               Company     Location_HQ        Industry  Laid_Off_Count  \
# 0        Thoughtworks         Chicago           Other           500.0
# 2               Waymo     SF Bay Area  Transportation           209.0
# 4           Yellow.ai     SF Bay Area         Support           200.0
# 5              Sonder     SF Bay Area          Travel           100.0
# 6     Electronic Arts     Baton Rouge        Consumer           200.0
# ...               ...             ...             ...             ...
# 2325     HopSkipDrive     Los Angeles  Transportation             8.0
# 2326      Panda Squad     SF Bay Area        Consumer             6.0
# 2327    Tamara Mellon     Los Angeles          Retail            20.0
# 2328         EasyPost  Salt Lake City       Logistics            75.0
# 2329        Blackbaud      Charleston           Other           500.0
#
#       Percentage            Date  \
# 0           0.04   3/1/2023 0:00
# 2           0.08   3/1/2023 0:00
# 4            NaN   3/1/2023 0:00
# 5           0.14   3/1/2023 0:00
# 6            NaN  2/28/2023 0:00
# ...          ...             ...
# 2325        0.10  3/13/2020 0:00
# 2326        0.75  3/13/2020 0:00
# 2327        0.40  3/12/2020 0:00
# 2328         NaN  3/11/2020 0:00
# 2329        0.14             NaN
#
#                                                  Source  Funds_Raised  \
# 0     https://techcrunch.com/2023/03/01/thoughtworks...         748.0
# 2     https://www.theinformation.com/articles/alphab...        5500.0
# 4     https://inc42.com/buzz/conversational-ai-start...         102.0
# 5     https://www.sec.gov/ix?doc=/Archives/edgar/dat...         839.0
# 6     https://kotaku.com/ea-apex-legends-bugs-layoff...           2.0
# ...                                                 ...           ...
# 2325  https://layoffs.fyi/2020/04/02/hopskipdrive-la...          45.0
# 2326  https://twitter.com/danielsinger/status/123854...           1.0
# 2327            https://layoffs.fyi/list/tamara-mellon/          90.0
# 2328  https://www.bizjournals.com/louisville/news/20...          12.0
# 2329  https://www.postandcourier.com/business/sc-tec...           NaN
#
#            Stage       Date_Added        Country List_of_Employees_Laid_Off
# 0       Post-IPO    3/2/2023 4:06  United States                    Unknown
# 2     Subsidiary    3/2/2023 4:08  United States                    Unknown
# 4       Series C    3/2/2023 4:12  United States                    Unknown
# 5       Post-IPO    3/2/2023 4:16  United States                    Unknown
# 6       Post-IPO    3/2/2023 4:10  United States                    Unknown
# ...          ...              ...            ...                        ...
# 2325     Unknown    4/3/2020 4:47  United States                    Unknown
# 2326        Seed   4/17/2020 0:12  United States                    Unknown
# 2327    Series C  3/31/2020 16:04  United States                    Unknown
# 2328    Series A  3/31/2020 13:21  United States                    Unknown
# 2329    Post-IPO  2/15/2023 19:06  United States                    Unknown
#
# [1527 rows x 12 columns]

# %% [markdown]
# ## Question 1: Which industries have the most layoffs for the years 2022 and 2023?
# #### Team Members: Ratima Chowadee, Lorena Egea

# %% [markdown]
# ## Question  2: Is there a correlation between the US state and the layoff rate? Which state has the most layoffs?
# #### Team Members: Toyin Olaye, Leslie Trejo, Camilla Inhapim

# %% [markdown]
# ## Question 3: Do companies have more layoffs pre-IPO or post-IPO?
# #### Team Members: Julie Tang, Sam Gantman

# %%
cleaned_mergedData
# Out:
#            Company     Location_HQ        Industry  Laid_Off_Count  \
# 0     Thoughtworks         Chicago           Other           500.0
# 1            Waymo   San Francisco  Transportation           209.0
# 2        Yellow.ai   San Francisco         Support           200.0
# 3           Sonder   San Francisco          Travel           100.0
# 4       Eventbrite   San Francisco        Consumer            80.0
# ..             ...             ...             ...             ...
# 885       Help.com          Austin         Support            16.0
# 886   HopSkipDrive     Los Angeles  Transportation             8.0
# 887    Panda Squad   San Francisco        Consumer             6.0
# 888  Tamara Mellon     Los Angeles          Retail            20.0
# 889       EasyPost  Salt Lake City       Logistics            75.0
#
#                Date  Funds_Raised       Stage        Country state_id  \
# 0     3/1/2023 0:00         748.0    Post-IPO  United States       IL
# 1     3/1/2023 0:00        5500.0  Subsidiary  United States       CA
# 2     3/1/2023 0:00         102.0    Series C  United States       CA
# 3     3/1/2023 0:00         839.0    Post-IPO  United States       CA
# 4    2/28/2023 0:00         557.0    Post-IPO  United States       CA
# ..              ...           ...         ...            ...      ...
# 885  3/16/2020 0:00           6.0        Seed  United States       TX
# 886  3/13/2020 0:00          45.0     Unknown  United States       CA
# 887  3/13/2020 0:00           1.0        Seed  United States       CA
# 888  3/12/2020 0:00          90.0    Series C  United States       CA
# 889  3/11/2020 0:00          12.0    Series A  United States       UT
#
#      state_name      lat       lng
# 0      Illinois  41.8373  -87.6862
# 1    California  37.7562 -122.4430
# 2    California  37.7562 -122.4430
# 3    California  37.7562 -122.4430
# 4    California  37.7562 -122.4430
# ..          ...      ...       ...
# 885       Texas  30.3004  -97.7522
# 886  California  34.1139 -118.4068
# 887  California  37.7562 -122.4430
# 888  California  34.1139 -118.4068
# 889        Utah  40.7777 -111.9306
#
# [890 rows x 12 columns]

# %%
# Pre_Post_data = cleaned_mergedData.loc[cleaned_mergedData["Stage"]!="Unknown"]
# Pre_Post_data

#Get rid of of rows with Stage= "Unknown"
#cleaned_mergedData = cleaned_mergedData[cleaned_mergedData["Stage"] != "Unknown"]
#Pre_Post_data = cleaned_mergedData["Stage"].unique()


Pre_Post_data = cleaned_mergedData[cleaned_mergedData["Stage"] != "Unknown"]
grouped_Pre_Post= Pre_Post_data.groupby("Stage").sum("Laid_Off_Count")
grouped_Pre_Post
# Out:
#                 Laid_Off_Count  Funds_Raised        lat         lng
# Stage
# Acquired               11181.0       14240.6  2431.9504  -6006.9729
# Post-IPO              144930.0      778778.6  8239.4225 -22696.9691
# Private Equity          2972.0       15369.0   624.8550  -1574.9363
# Seed                     264.0          66.0   406.4540  -1217.0736
# Series A                2113.0        3725.4  2058.8917  -5429.9074
# Series B                7550.0       12820.6  4399.5401 -11770.2657
# Series C               10100.0       21940.6  4695.9441 -13272.0528
# Series D                9699.0       33885.6  3806.3636 -10359.8645
# Series E                8664.0       35758.0  2339.0434  -6120.1092
# Series F                5505.0       18681.0  1360.0421  -3281.7470
# Series G                1230.0        8988.0   335.5027   -875.2755
# Series H                4944.0       29360.0   584.1148  -1492.0856
# Series I                 195.0        1176.0    71.8701   -240.8498
# Subsidiary               359.0        8200.0    75.5124   -244.8860

# %%
#Pie Chart of Total Laid_Off_count for all Stages
labels = grouped_Pre_Post.index
plt.pie(grouped_Pre_Post["Laid_Off_Count"],labels=labels, rotatelabels=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1aed5494d90>,
#   <matplotlib.patches.Wedge at 0x1aed54a12b0>,
#   <matplotlib.patches.Wedge at 0x1aed54a1790>,
#   <matplotlib.patches.Wedge at 0x1aed54a1c70>,
#   <matplotlib.patches.Wedge at 0x1aed54ae190>,
#   <matplotlib.patches.Wedge at 0x1aed54ae670>,
#   <matplotlib.patches.Wedge at 0x1aed54aeb50>,
#   <matplotlib.patches.Wedge at 0x1aed54fa0a0>,
#   <matplotlib.patches.Wedge at 0x1aed54fa580>,
#   <matplotlib.patches.Wedge at 0x1aed54faa60>,
#   <matplotlib.patches.Wedge at 0x1aed5494d60>,
#   <matplotlib.patches.Wedge at 0x1aed5508430>,
#   <matplotlib.patches.Wedge at 0x1aed5508910>,
#   <matplotlib.patches.Wedge at 0x1aed5508df0>],
#  [Text(1.0846047631330105, 0.183391678625794, 'Acquired'),
#   Text(-0.885316849846192, 0.652850729783168, 'Post-IPO'),
#   Text(0.010464173601110984, -1.09995022663339, 'Private Equity'),
#   Text(0.06375473223287079, -1.098150870380712, 'Seed'),
#   Text(0.1028108640336588, -1.0951848822169947, 'Series A'),
#   Text(0.25972221778891136, -1.0688986713373767, 'Series B'),
#   Text(0.5300452706615303, -0.9638734414067779, 'Series C'),
#   Text(0.7886186998161552, -0.7668640989773071, 'Series D'),
#   Text(0.9672758611871548, -0.5238104698883446, 'Series E'),
#   Text(1.0559200964669009, -0.30827382288694394, 'Series F'),
#   Text(1.0816009936308109, -0.20034792381465502, 'Series G'),
#   Text(1.0954820687266011, -0.09959436278468131, 'Series H'),
#   Text(1.0998971116638852, -0.015044725103613958, 'Series I'),
#   Text(1.0999840923963387, -0.005915781858997064, 'Subsidiary')])

# %%
plt.barh(labels, width=grouped_Pre_Post["Laid_Off_Count"])
# Out:
# <BarContainer object of 14 artists>

# %%
#Look at Post-IPO companies
Post_IPO_companies = Pre_Post_data.loc[Pre_Post_data["Stage"]=="Post-IPO"] #& "2023" in Pre_Post_data["Date"]]
sorted_post_ipo_companies=Post_IPO_companies.sort_values("Laid_Off_Count",ascending=False).reset_index()
top10 = sorted_post_ipo_companies.iloc[0:10,:]
top10
#plt.barh(top10["Company"], width=top10["Laid_Off_Count"])
# Out:
#    index     Company    Location_HQ        Industry  Laid_Off_Count  \
# 0     92      Google  San Francisco        Consumer         12000.0
# 1    227        Meta  San Francisco        Consumer         11000.0
# 2    202      Amazon        Seattle          Retail         10000.0
# 3    104   Microsoft        Seattle           Other         10000.0
# 4    143      Amazon        Seattle          Retail          8000.0
# 5    144  Salesforce  San Francisco           Sales          8000.0
# 6    203       Cisco  San Francisco  Infrastructure          4100.0
# 7    671        Uber  San Francisco  Transportation          3700.0
# 8    240     Twitter  San Francisco        Consumer          3700.0
# 9    651        Uber  San Francisco  Transportation          3000.0
#
#               Date  Funds_Raised     Stage        Country state_id  \
# 0   1/20/2023 0:00          26.0  Post-IPO  United States       CA
# 1   11/9/2022 0:00       26000.0  Post-IPO  United States       CA
# 2  11/16/2022 0:00         108.0  Post-IPO  United States       WA
# 3   1/18/2023 0:00           1.0  Post-IPO  United States       WA
# 4    1/4/2023 0:00         108.0  Post-IPO  United States       WA
# 5    1/4/2023 0:00          65.0  Post-IPO  United States       CA
# 6  11/16/2022 0:00           2.0  Post-IPO  United States       CA
# 7    5/6/2020 0:00       24700.0  Post-IPO  United States       CA
# 8   11/4/2022 0:00       12900.0  Post-IPO  United States       CA
# 9   5/18/2020 0:00       24700.0  Post-IPO  United States       CA
#
#    state_name      lat       lng
# 0  California  37.7562 -122.4430
# 1  California  37.7562 -122.4430
# 2  Washington  47.6211 -122.3244
# 3  Washington  47.6211 -122.3244
# 4  Washington  47.6211 -122.3244
# 5  California  37.7562 -122.4430
# 6  California  37.7562 -122.4430
# 7  California  37.7562 -122.4430
# 8  California  37.7562 -122.4430
# 9  California  37.7562 -122.4430

# %% [markdown]
# ## Question 4: Does the amount of funds raised impact the layoff rates?
# #### Team Members: Taylor Gibson, Arthi Ranganathan
